# %% [markdown]
# ### AB 12970

# %%
AAAAA 0
ABAAA 1
AABAA 2
AAABA 3
AAAAB 4
ABAAB 4
AABAB 5
AAABB 6

AAAAAA 0


AABAABAAB 2+4+6

# %%
AAAAAAA
AAABBBB 12
AAAABBB 12
AABBBBB 10


3 * 4
2 * 5
1 * 6

# %%
7: 3 * 4 12
8: 4 * 4 16

# %%
AAAAABBB  5 * 3
AAAABBBB 4 * 4
AAABBBBB 3 * 5


AB 1
BA 0

ABA 0
BAA 0

ABB 2
BAB 1

# %%
needed   4
AAABBB   9
AAAABB   8
AAAAAB   5
AAAABB   4

# %%
needed   6
AAABBB   9
AAAABB   8
AAAAAB   5
AABAAB   6

# %%
needed   8
AAABBB   9
AAAABB   8
AAAAAB   5
AABAAB   6

# %%
needed   2
AAABBB   9
AAAABB   8
AAAAAB   5
AAAAAA   0
AAAABA

# %%
AAAABBB  12
AAAAABB  10
AAAAAAB  5

# %%
def get_count(li):
    total = 0
    ca = 0
    for v in li:
        if v == 'A':
            ca += 1
        else:
            total += ca
            
    return total

n, k = map(int, input().split())

if n % 2 == 0 and (n // 2) ** 2 < k:
    print(-1)
elif n % 2 == 1 and (n // 2) * (n // 2 + 1) < k:
    print(-1)
else:
    ca = n // 2
    if n % 2 == 1:
        ca += 1
    cb = n // 2

    li = ['A'] * ca + ['B'] * cb

    while True:
        c = get_count(li)

        if c == k:
            break
        if c > k:
            for i in range(n):
                if li[i] == 'B':
                    li[i] = 'A'
                    break
        else:
            for i in range(n):
                if li[i] == 'A':
                    nli = li.copy()
                    nli[i] = 'B'
                    nc = get_count(nli)
                    if nc == k:
                        li = nli.copy()
                        break

    print(''.join(li))
# Out:
# 12 32
# AAAAAAAABBBB

# %%
12 35
AAAAAAABBBBB

# %%
12 34
AAAAAABABBBB

# %%
12 33
AAAAABAABBBB

# %%
ABBBBB 5
AABBBB 8
AAABBB 9
AAAABB 8
AAAAAB 5

AAABAB 3+4 7
AABAAB 2+4 6
ABAAAB 1+4 5
BAAAAB 4   4

AAAAAABBBBBB 6*6  36
AAAAAAABBBBB 7*5  35

AAAAAAAABBBB 8*4  24
AAAAAAAAABBB 9*3  27
AAAAAAAAAABB 10*2 20
AAAAAAAAAAAB 11*1 11

# %% [markdown]
# ### 고득점 3663

# %%
from collections import deque
import sys
# input = lambda: sys.stdin.readline().rstrip()

inf = float('inf')

for _ in range(int(input())):
    s = input()
    n = len(s)

    if s.count('A') == n:
        print(0)
    else:
        r = 0
        intv = []
        for i in range(n):
            num = ord(s[i])

            t1 = num - 65
            t2 = 91 - num

            r += min(t1, t2)    

            if s[i] != 'A' and i + 1 < n and s[i + 1] == 'A':
                intv.append([i, n])
            if intv and s[i] == 'A' and i + 1 < n and s[i + 1] != 'A':
                intv[-1][-1] = i + 1

        t1 = 0
        for i in range(1, n):
            if s[i] != 'A':
                t1 = i

        t2 = 0
        for i in range(n - 1, -1, -1):
            if s[i] != 'A':
                t2 = n - i

        t3 = inf
        for s, e in intv:
            aa = s
            bb = n - e
            t3 = min(t3, min(aa, bb) * 2 + max(aa, bb))

        r += min(t1, t2, t3)

        print(r)
# Out:
# JAN
# 23

# %% [markdown]
# ### 연금술사 19857

# %%
# 틀렸음
n = int(input())
li = list(map(int, input().split()))

sli = [0] * (n + 1)
cumul = 0
for i in range(n):
    cumul += li[i]
    sli[i] = cumul
sli[-1] = sli[-2]

if sli[-1] == 1:
    r = 1
    for i in range(n - 1, -1, -1):
        if li[i] == 1:
            r = max(i, r)
            break
    print(r)
else:
    start = 1
    end = int(1e10)
    max_r = 1
    while start <= end:
        mid = (start + end) // 2
        nli = li.copy()

        if mid <= n:
            nli[0] += sli[-1] - sli[mid - 1]

        per_needed = 0
         
        
        
        
        for i in range(mid - 1, 0, -1):
            nli[i] -= per_needed
            if nli[i] < 1:
                per_needed += 1 - nli[i]
                nli[i] = 1
            else:
                nli[0] += nli[i] - 1
                nli[i] = 1

        nli[0] -= per_needed

        if nli[0] >= 1:
            max_r = mid
            start = mid + 1
        else:
            end = mid - 1 

    print(max_r)

# %% [markdown]
# https://www.acmicpc.net/problem/17371 이사

# %%
서로 간에 가장 먼 두 점의 중간 지점을 선택하면 어떨까?

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

n = int(input())
li = [list(map(int, input().split())) for _ in range(n)]

get_dist_s = lambda x1, y1, x2, y2: (x1 - x2) ** 2 + (y1 - y2) ** 2

max_dist = -1
max_dist_ps = ()
for i in range(n):
    for j in range(i, n):
        dist = get_dist_s(*li[i], *li[j])
        
        if dist > max_dist:
            max_dist = dist
            max_dist_ps = (i, j)

ti, tj = max_dist_ps[0], max_dist_ps[1]

x1, y1 = li[ti]
print(x1, y1)
# Out:
# 5
# -4 1
# 0 -3
# 0 1
# 2 2
# 4 -3
# 0.0 -1.0

# %%
ti, tj
# Out:
# (0, 4)

# %%
a = 3
a **= 4

# %% [markdown]
# https://www.acmicpc.net/problem/10885 수열의 장인

# %%
import io, os, sys
# input = io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

mod = 1000000007 

def get_value(s, e):
    s += 1
    e -= 1
    if s > e:
        return -2
    
    c1 = 0
    c2 = 0
    cm = 0
    for i in range(s, e + 1):
        if li[i] < 0:
            cm += 1
        if abs(li[i]) == 2:
            c2 += 1
        else:
            c1 += 1
            
    if cm % 2 == 0:
        return c2
    
    nc1 = c1
    nc2 = c2
    for i in range(s, e + 1):
        if abs(li[i]) == 2:
            nc2 -= 1
        else:
            nc1 -= 1
        if li[i] < 0:
            break
    cand1 = (nc1, nc2)
    
    nc1 = c1
    nc2 = c2
    for i in range(e, s - 1, -1):
        if abs(li[i]) == 2:
            nc2 -= 1
        else:
            nc1 -= 1
        if li[i] < 0:
            break    
    cand2 = (nc1, nc2)
    
    if cand1[1] > cand2[1]:
        return cand1[1]
    elif cand1[1] < cand2[1]:
        return cand2[1]
    else:
        if cand1[1]:
            return cand1[1]
        else:
            if cand1[0] or cand2[0]:
                return 0
            else:
                return -1

for _ in range(int(input())):
    n = int(input())
    li = list(map(int, input().split()))

    recent_zero_i = -1
    max_v = -2

    max_plus_c2 = -1
    for i in range(n):
        max_v = max(max_v, li[i])
        if li[i] == 0:
            max_plus_c2 = max(max_plus_c2, get_value(recent_zero_i, i))
            recent_zero_i = i   
    max_plus_c2 = max(max_plus_c2, get_value(recent_zero_i, n))

    if max_plus_c2 >= 0:
        result = pow(2, max_plus_c2, mod)
    else:
        result = max_v % mod

    print(result)
# Out:
# 1
# 1
# -1
# -1

# %% [markdown]
# https://www.acmicpc.net/problem/1508 레이스

# %%
def check(mid):
    cur = li[0]
    used_m = 1
    result = [0] * k
    result[0] = 1
    for i in range(1, k):
        if li[i] - cur >= mid:
            result[i] = 1
            used_m += 1
            cur = li[i]
            
    if used_m >= m:
        return result
    return []

n, m, k = map(int, input().split())
li = list(map(int, input().split()))

start = 0
end = n
result = []
while start <= end:
    mid = (start + end) // 2
    
    r = check(mid)
    if r:
        result = r
        start = mid + 1
    else:
        end = mid - 1
        
over_c = result.count(1) - m
for i in range(k - 1, -1, -1):
    if over_c and result[i]:
        result[i] = 0
        over_c -= 1
        
print(''.join(map(str, result)))
# Out:
# 11 3 4
# 0 5 10 11
# 1110

# %% [markdown]
# https://www.acmicpc.net/problem/3430 용이 산다

# %%
from collections import deque
import io, os, sys
# input = io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

for _ in range(int(input())):
    n, m = map(int, input().split())
    li = list(map(int, input().split()))

    queue = deque()
    ip = True
    zero_status = []
    for i in range(m):
        num = li[i]

        if num == 0:
            sst.add(i)
        else:
            if rain_fore[num] == -1:
                rain_fore[num] = i
            else:
                to_prepare_i = rain_fore[num]
                index = sst.index(to_prepare_i)
                index -= 1
                if index == -1:
                    ip = False
                    break
                else:
                    zi = sst[index]
                    zero_status.append((zi, num))
                    sst.discard(zi)
                    rain_fore[num] = i

    if not ip:
        print('NO')
    else:      
        for zi in sst:
            zero_status.append((zi, 0))

        zero_status.sort(key=lambda x: x[0])
        result = [v[1] for v in zero_status]

        print('YES')
        print(*result)
# Out:
# 6 3
# 3 0 3
# NO

# %%
import io, os, sys
# input = io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

# https://github.com/tatyam-prime/SortedSet/blob/main/SortedSet.py
import math
from bisect import bisect_left, bisect_right
from typing import Generic, Iterable, Iterator, TypeVar, Union, List
T = TypeVar('T')

class SortedSet(Generic[T]):
    BUCKET_RATIO = 50
    REBUILD_RATIO = 170

    def _build(self, a=None) -> None:
        "Evenly divide `a` into buckets."
        if a is None: a = list(self)
        size = self.size = len(a)
        bucket_size = int(math.ceil(math.sqrt(size / self.BUCKET_RATIO)))
        self.a = [a[size * i // bucket_size : size * (i + 1) // bucket_size] for i in range(bucket_size)]
    
    def __init__(self, a: Iterable[T] = []) -> None:
        "Make a new SortedSet from iterable. / O(N) if sorted and unique / O(N log N)"
        a = list(a)
        if not all(a[i] < a[i + 1] for i in range(len(a) - 1)):
            a = sorted(set(a))
        self._build(a)

    def __iter__(self) -> Iterator[T]:
        for i in self.a:
            for j in i: yield j

    def __reversed__(self) -> Iterator[T]:
        for i in reversed(self.a):
            for j in reversed(i): yield j
    
    def __len__(self) -> int:
        return self.size
    
    def __repr__(self) -> str:
        return "SortedSet" + str(self.a)
    
    def __str__(self) -> str:
        s = str(list(self))
        return "{" + s[1 : len(s) - 1] + "}"

    def _find_bucket(self, x: T) -> List[T]:
        "Find the bucket which should contain x. self must not be empty."
        for a in self.a:
            if x <= a[-1]: return a
        return a

    def __contains__(self, x: T) -> bool:
        if self.size == 0: return False
        a = self._find_bucket(x)
        i = bisect_left(a, x)
        return i != len(a) and a[i] == x

    def add(self, x: T) -> bool:
        "Add an element and return True if added. / O(√N)"
        if self.size == 0:
            self.a = [[x]]
            self.size = 1
            return True
        a = self._find_bucket(x)
        i = bisect_left(a, x)
        if i != len(a) and a[i] == x: return False
        a.insert(i, x)
        self.size += 1
        if len(a) > len(self.a) * self.REBUILD_RATIO:
            self._build()
        return True

    def discard(self, x: T) -> bool:
        "Remove an element and return True if removed. / O(√N)"
        if self.size == 0: return False
        a = self._find_bucket(x)
        i = bisect_left(a, x)
        if i == len(a) or a[i] != x: return False
        a.pop(i)
        self.size -= 1
        if len(a) == 0: self._build()
        return True
    
    def lt(self, x: T) -> Union[T, None]:
        "Find the largest element < x, or None if it doesn't exist."
        for a in reversed(self.a):
            if a[0] < x:
                return a[bisect_left(a, x) - 1]

    def le(self, x: T) -> Union[T, None]:
        "Find the largest element <= x, or None if it doesn't exist."
        for a in reversed(self.a):
            if a[0] <= x:
                return a[bisect_right(a, x) - 1]

    def gt(self, x: T) -> Union[T, None]:
        "Find the smallest element > x, or None if it doesn't exist."
        for a in self.a:
            if a[-1] > x:
                return a[bisect_right(a, x)]

    def ge(self, x: T) -> Union[T, None]:
        "Find the smallest element >= x, or None if it doesn't exist."
        for a in self.a:
            if a[-1] >= x:
                return a[bisect_left(a, x)]
    
    def __getitem__(self, x: int) -> T:
        "Return the x-th element, or IndexError if it doesn't exist."
        if x < 0: x += self.size
        if x < 0: raise IndexError
        for a in self.a:
            if x < len(a): return a[x]
            x -= len(a)
        raise IndexError
    
    def index(self, x: T) -> int:
        "Count the number of elements < x."
        ans = 0
        for a in self.a:
            if a[-1] >= x:
                return ans + bisect_left(a, x)
            ans += len(a)
        return ans

    def index_right(self, x: T) -> int:
        "Count the number of elements <= x."
        ans = 0
        for a in self.a:
            if a[-1] > x:
                return ans + bisect_right(a, x)
            ans += len(a)
        return 

for _ in range(int(input())):
    n, m = map(int, input().split())
    li = list(map(int, input().split()))
    
    rain_fore = [-1] * (n + 1)
    sst = SortedSet()
    ip = True
    for i in range(m - 1, -1, -1):
        num = li[i]

        if num == 0:
            sst.add(i)
        else:
            if rain_fore[num] == -1:
                rain_fore[num] = i
            else:
                to_prepare_i = rain_fore[num]
                index = sst.index(to_prepare_i)
                index -= 1
                if index == -1:
                    ip = False
                    break
                else:
                    zi = sst[index]
                    li[zi] = n + num
                    sst.discard(zi)
                    rain_fore[num] = i
   
    for num in range(1, n + 1):
        if rain_fore[num] != -1:
            to_prepare_i = rain_fore[num]
            index = sst.index(to_prepare_i)
            index -= 1
            if index == -1:
                ip = False
                break
            else:
                zi = sst[index]
                li[zi] = n + num
                sst.discard(zi)

    if not ip:
        print('NO')
    else:
        result = []
        for v in li:
            if v == 0:
                result.append(0)
            elif v > n:
                result.append(v - n)

        print('YES')
        print(*result)
# Out:
# 1
# 2 4
# 0 1 0 2
# YES
# 1 2

# %% [markdown]
# https://www.acmicpc.net/problem/17371 이사

# %%
import io, os, sys
# input = io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

inf = float('inf')

def get_dist_s(a, b):
    ax, ay = a
    bx, by = b
    
    return (ax - bx) ** 2 + (ay - by) ** 2

n = int(input())
li = [list(map(int, input().split())) for _ in range(n)]

min_max_dist_s = inf
min_max_dist_s_i = -1
for i in range(n):
    max_dist_s = 0
    for j in range(n):
        dist_s = get_dist_s(li[i], li[j])
        max_dist_s = max(max_dist_s, dist_s)
        
    if max_dist_s < min_max_dist_s:
        min_max_dist_s = max_dist_s
        min_max_dist_s_i = i
        
print(*li[min_max_dist_s_i])
# Out:
# 3
# 0 0
# 0 5
# 0 10
# 0 5
