# %% [markdown]
# ### 캠프 준비 16938

# %%
난이도 차 조건은 윈도우 설정하는 식으로 가능해보임

-> 2 ** n 브루트포스

# %%
from itertools import product

n, l, r, x = map(int, input().split())
li = sorted(map(int, input().split()))

c = 0
for case in product(*[range(2)] * n):
    nli = []
    for i in range(n):
        if case[i]:
            nli.append(li[i])
    
    if len(nli) <= 1:
        continue
    if nli[-1] - nli[0] < x:
        continue
    sv = sum(nli)
    if l <= sv <= r:
        c += 1

print(c)

# %% [markdown]
# ### 나3곱 16936

# %%
3의 배수가 아닌 수에 2를 계속 곱해도 3의 배수가 될 수 없음


3이 얼마나 들어가 있는지를 파악하면 됨

# %%
n = int(input())
li = list(map(int, input().split()))

nli = []
for value in li:
    c = 0
    v = value
    while True:
        if v % 3 == 0:
            c += 1
            v //= 3
        else:
            break
    nli.append((value, c))
    
nli.sort(key=lambda x: (-x[1], x[0]))

r = [v[0] for v in nli]

print(*r)

# %% [markdown]
# ### Ezreal 여눈부터 가네 ㅈㅈ 20500

# %%
3의 배수이면서 5의 배수여야 함

5의 배수려면 끝이 5여야 함
3의 배수려면 총합이 3이어야함

맨 끝은 5로 고정됨

# %%
mod = 1000000007

max_num = 1515

factos = [0] * (max_num + 1)
factos[0] = 1
invs = [0] * (max_num + 1)
cur = 1
for i in range(1, max_num + 1):
    cur *= i
    cur %= mod
    factos[i] = cur
    
invs[max_num] = pow(factos[max_num], mod - 2, mod)
for i in range(max_num - 1, -1, -1):
    invs[i] = (i + 1) * invs[i + 1] % mod

n = int(input())

n -= 1
r = 0
for c1 in range(n + 1):
    c5 = n - c1
    
    if (c1 + c5 * 5 + 5) % 3 == 0:
        r += factos[n] * invs[c5] * invs[n - c5] % mod
        r %= mod
        
print(r)

# %%
n = 0
for _ in range(50000):
    n += 15
    
    st = set(str(n))
    if '1' in st and '5' in st and len(st) == 2:
        print(n)

# %% [markdown]
# ### 애너그램 6443

# %%
from collections import Counter, defaultdict as dd
import sys
input = lambda: sys.stdin.readline().rstrip()

def recur(cur):
    if len(cur) == n:
        r.append(''.join(cur))
        return
    
    needed = []
    for key in ct:
        if counts[key] < ct[key]:
            needed.append(key)

    for v in needed:
        cur.append(v)
        counts[v] += 1
        recur(cur)
        cur.pop()
        counts[v] -= 1
            
for _ in range(int(input())):
    s = input()
    ct = Counter(s)
    n = len(s)

    li = list(set(s))

    r = []
    counts = dd(int)
    recur([])

    print('\n'.join(sorted(r)))
# Out:
# 1
# aaa
# aaa

# %% [markdown]
# ### ATM놀이 7481

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

for _ in range(int(input())):
    a, b, s = map(int, input().split())

    is_reversed = False
    if b < a:
        is_reversed = True
        a, b = b, a

    rac = rbc = -1
    for ac in range(10002):
        temp = s - a * ac
        if temp < 0:
            break
        if temp % b == 0:
            rac = ac
            rbc = temp // b
            break

    if rac == -1:
        print('Impossible')
    else:
        if is_reversed:
            rac, rbc = rbc, rac

        print(rac, rbc)

# %% [markdown]
# ### 자리수의 제곱 4881

# %%
import sys
# input = lambda: sys.stdin.readline().rstrip()

def calcul(num):
    sv = 0
    for v in str(num):
        sv += int(v) ** 2
    return sv

while True:
    oa,ob = map(int, input().split())
    if oa == 0 and ob == 0:
        break

    a = oa
    a_st = set()
    a_li = list()
    while True:
        if a in a_st:
            break
        a_st.add(a)
        a_li.append(a)

        a = calcul(a)

    b = ob
    b_st = set()
    b_li = list()
    while True:
        if b in b_st:
            break
        b_st.add(b)    
        b_li.append(b)

        b = calcul(b)

    r = float('inf')
    for ai in range(len(a_li)):
        if a_li[ai] in b_st:
            r = min(r, ai + b_li.index(a_li[ai]) + 2)
    
    if r == float('inf'):
        r = 0
        
    print(oa, ob, r)
# Out:
# 89 89
# 89 89 2
# 19 100
# 19 100 5
# 61 19
# 61 19 0
# 0 0

# %% [markdown]
# ### Ax+Bsin(x)=C 14786

# %%
import math
from decimal import getcontext, Decimal
getcontext().prec = 100

a, b, c = input().split()
c = Decimal(c)

start = Decimal("0")
end = Decimal("100000")
diff = Decimal("0.00000000001")

while True:
    x = (start + end) / Decimal("2")
    
    left = Decimal(a) * Decimal(x) + Decimal(b) * Decimal(math.sin(x)) 
    
    if left - diff <= c <= left + diff:
        break
    elif left < c:
        start = x
    else:
        end = x
        
print(x)
# Out:
# 100000 100000 100000
# 0.51097342938856908539408015201832569118778337724506855010986328125

# %% [markdown]
# ### Equations 4341

# %%
from math import gcd
import sys
input = lambda: sys.stdin.readline().rstrip()

def get_info(li):
    info = [0, 0, 0]
    
    for i in range(1, len(li), 2):
        if li[i] == '+':
            li[i] = 1
        else:
            li[i] = -1

    for i in range(0, len(li), 2):
        cur_o = 1
        if i >= 1:
            cur_o = li[i - 1]
        
        if '-' in li[i]:
            cur_o = -cur_o
            
        digit = []
        va = ''
        for v in li[i]:
            if v.isdigit():
                digit.append(v)
            else:
                if v != '-':
                    va = v
                
        digit = ''.join(digit)      
        if not digit:
            digit = '1'
            
        digit = int(digit)
        digit *= cur_o
        
        if va == 'x':
            info[0] += digit
        elif va == 'y':
            info[1] += digit
        else:
            info[2] += digit
            
    return info

def grv(var):
    '''get result var'''
    
    state = 1
    if var[0] < 0:
        var[0] = -var[0]
        state = -state
    if var[1] < 0:
        var[1] = -var[1]
        state = -state
    g = gcd(var[0], var[1])
    for i in range(2):
        var[i] //= g
    if var[1] == 1:
        return var[0] * state
    else:            
        return f'{var[0] * state}/{var[1]}'
    
def minus_frac(r, to_minus):
    rr = [r * to_minus[1], to_minus[1]]
    return [rr[0] - to_minus[0], rr[1]]

t = int(input())
for tn in range(t):
    a = input()
    b = input()

    a_left, a_right = a.split(' = ')

    a_left = a_left.split()
    a_right = a_right.split()

    al= get_info(a_left)
    ar = get_info(a_right)

    for i in range(2):
        al[i] -= ar[i]
        ar[i] = 0

    ar[2] -= al[2]
    al[2] = 0

    al.pop()
    ar = ar[2]


    b_left, b_right = b.split(' = ')

    b_left = b_left.split()
    b_right = b_right.split()

    bl= get_info(b_left)
    br = get_info(b_right)

    for i in range(2):
        bl[i] -= br[i]
        br[i] = 0

    br[2] -= bl[2]
    bl[2] = 0

    bl.pop()
    br = br[2]

    dn = "don't know"
    rx = ''
    ry = ''
    if al[0] == 0 and al[1] == 0 and ar or bl[0] == 0 and bl[1] == 0 and br:
        rx = ry = dn
    elif al[0] and al[1] and bl[0] and bl[1]:
        nal = al.copy()
        nar = ar
        nbl = bl.copy()
        nbr = br

        for i in range(2):
            nal[i] *= bl[0]
        nar *= bl[0]

        for i in range(2):
            nbl[i] *= al[0]
        nbr *= al[0]

        dl = [0, 0]
        for i in range(2):
            dl[i] = nal[i] - nbl[i]
        dr = nar - nbr

        if dl[1] == 0:
            rx = ry = dn
        else:
            y = [dr, dl[1]]
            temp = y.copy()
            temp[0] *= al[1]
            temp = minus_frac(ar, temp)
            temp[1] *= al[0]
            x = temp
            rx, ry = grv(x), grv(y)
    else:
        if al[0] == 0 and al[1] == 0 and bl[0] == 0 and bl[1] == 0:
            rx = ry = dn
        elif al[0] == 0 and al[1] == 0:
            if bl[0] and bl[1]:
                rx = ry = dn
            elif bl[0] and bl[1] == 0:
                x = [br, bl[0]]
                rx, ry = grv(x), dn
            elif bl[0] == 0 and bl[1]:
                y = [br, bl[1]]
                rx, ry = dn, grv(y)
        elif bl[0] == 0 and bl[1] == 0:
            if al[0] and al[1]:
                rx, ry = dn, dn
            elif al[0] and al[1] == 0:
                x = [ar, al[0]]
                rx, ry = grv(x), dn       
            elif al[0] == 0 and al[1]:
                y = [ar, al[1]]
                rx, ry = dn, grv(y)
        elif al[0] and al[1]:
            if bl[0]:
                x = [br, bl[0]]
                temp = x.copy()
                temp[0] *= al[0]
                temp = minus_frac(ar, temp)
                temp[1] *= al[1]
                y = temp
                rx, ry = grv(x) ,grv(y)
            elif bl[1]:
                y = [br, bl[1]]
                temp = y.copy()
                temp[0] *= al[1]
                temp = minus_frac(ar, temp)
                temp[1] *= al[0]
                x = temp
                rx, ry = grv(x) ,grv(y)
        elif bl[0] and bl[1]:
            if al[0]:
                x = [ar, al[0]]
                temp = x.copy() 
                temp[0] *= bl[0]
                temp = minus_frac(br, temp)
                temp[1] *= bl[1]
                y = temp
                rx, ry = grv(x) ,grv(y)
            elif al[1]:
                y = [ar, al[1]]
                temp = y.copy()
                temp[0] *= bl[1]
                temp = minus_frac(br, temp)
                temp[1] *= bl[0]
                x = temp
                rx, ry = grv(x) ,grv(y)
        elif al[0] and bl[0]:
            x1 = [ar, al[0]]
            x1 = grv(x1)
            x2 = [br, bl[0]]
            x2 = grv(x2)    
            if x1 != x2:
                rx, ry = dn, dn
            else:
                rx, ry = x1, dn
        elif al[1] and bl[1]:
            y1 = [ar, al[1]]
            y1 = grv(y1)
            y2 = [br, bl[1]]
            y2 = grv(y2)    
            if y1 != y2:
                rx, ry = dn, dn
            else:
                rx, ry = dn, y1
        elif al[0] and bl[1]:
            x = [ar, al[0]]
            x = grv(x)
            y = [br, bl[1]]
            y = grv(y)
            rx, ry = x, y
        elif al[1] and bl[0]:
            x = [br, bl[0]]
            x = grv(x)
            y = [ar, al[1]]
            y = grv(y)
            rx, ry = x, y
            
    print(rx)
    print(ry)
            
    if tn != t - 1:
        print()
        input()
# Out:
# x = 1
# 3x = 6y
# 1
# 1/2

# %%
3x + 3y = 6
3x = 3

# %%
3x + 3y = 6
3y = 3

# %%
al
# Out:
# [3, 3]

# %%
bl
# Out:
# [3, 0]

# %%
def minus_frac(r, to_minus):
    rr = [r * to_minus[1], to_minus[1]]
    return [rr[0] - to_minus[0], rr[1]]

minus_frac(3, [1, 3])
# Out:
# [8, 3]

# %%
-3 - -4y - -5x + 5 = 1

# %%
for i in range(2):
    al_info[i] -= ar_info[i]
    ar_info[i] = 0
    
ar_info[2] -= al_info[2]
al_info[2] = 0

al_info, ar_info


al_info.pop()
ar_info = ar_info[2]
# Out:
# ([5, 4, 0], [0, 0, -1])

# %%
al_info, ar_info
# Out:
# ([5, 4], -1)

# %% [markdown]
# ### K-세준수 1418

# %%
n = int(input())
k = int(input())

def p_facto(num):
    r = []
    for mod in range(2, int(num ** 0.5) + 1):
        while num % mod == 0:
            num //= mod
            r.append(mod)
    
    if num != 1:
        r.append(num)
        
    if not r:
        r = [1]
        
    return r

r = 0
for i in range(1, n + 1):
    if p_facto(i)[-1] <= k:
        r += 1
        
print(r)
# Out:
# 100000
# 100
# 17442

# %% [markdown]
# ### 귀찮아 (SIB) 14929

# %%
n = int(input())
li = list(map(int, input().split()))

sli = [0] * n
cumul = 0
for i in range(n):
    cumul += li[i]
    sli[i] = cumul
    
total = 0
for i in range(n - 1, 0, -1):
    total += li[i] * sli[i - 1]
    
print(total)
# Out:
# 3
# 1 -2 3
# -5

# %% [markdown]
# ### 제곱 ㄴㄴ 수 1016

# %%
n, m = map(int, input().split())

# %%
1000001000000 ** 0.5
# Out:
# 1000000.499999875

# %%
1100000

# %%
max_num = 1100000
sp = [0] * (max_num + 1)
primes = []
for i in range(2, max_num + 1):
    if sp[i] == 0:
        sp[i] = i
        primes.append(i)
        
    j = 0
    while j < len(primes) and i * primes[j] <= max_num and primes[j] <= sp[i]:
        sp[i * primes[j]] = primes[j]
        j += 1

# %%
max_num = 1000001
sp = [0] * (max_num + 1)
primes = []
for i in range(2, max_num + 1):
    if sp[i] == 0:
        sp[i] = i
        primes.append(i)
        
    j = 0
    while j < len(primes) and i * primes[j] <= max_num and primes[j] <= sp[i]:
        sp[i * primes[j]] = primes[j]
        j += 1

primes_s = [v ** 2 for v in primes]
        
a, b = map(int, input().split())

total = 0
used = 0
for num in range(a, b + 1):
    ip = True
    for p in primes_s:
        used += 1
        if p > num:
            break
        if num % p == 0:
            ip = False
            break
                
    if ip:
        total += 1
        
print(used)
print(total)
# Out:
# 100000 110000
# 415064
# 6086

# %%
len(primes_s)
# Out:
# 85714

# %%
max_num = 1000005
sp = [0] * (max_num + 1)
primes = []
for i in range(2, max_num + 1):
    if sp[i] == 0:
        sp[i] = i
        primes.append(i)
        
    j = 0
    while j < len(primes) and i * primes[j] <= max_num and primes[j] <= sp[i]:
        sp[i * primes[j]] = primes[j]
        j += 1

a, b = map(int, input().split())

intv_len = b - a + 1
rs = [True] * intv_len
for p in primes:
    p_s = p ** 2
    
    remained = a % p_s
    
    if not remained:
        cur = 0
    else:
        lacks = p_s - remained
        cur = lacks
    
    while cur < intv_len:
        rs[cur] = False
        cur += p_s
        
print(sum(rs))
# Out:
# 1 10
# 7

# %% [markdown]
# https://www.acmicpc.net/problem/1111 IQ Test

# %%
n = int(input())
li = list(map(int, input().split()))

if n == 1:
    print('A')
elif n == 2:
    if li[0] == li[1]:
        print(li[0])
    elif li[0] == 0:
        print(li[1] * 2)
    else:
        print('A')
else:
    cands = set()
    for a in range(-1000, 1001):
        for b in range(-1000, 1001):
            if li[0] * a + b == li[1] and li[1] * a + b == li[2]:
                cands.add((a, b))
        
    rs = set()
    for a, b in cands:
        ip = True
        for i in range(n - 1):
            if li[i] * a + b != li[i + 1]:
                ip = False
                break
                
        if ip:
            print(a, b, li[-1] * a + b)
            
            rs.add((li[-1] * a + b))
            if len(rs) >= 2:
                break
    
    if not rs:
        print('B')
    elif len(rs) == 2:
        print('A')
    else:
        r = rs.pop()
        
        print(r)
# Out:
# 3
# 1 1 1
# 839 -838 1
# -966 967 1
# -198 199 1
# -531 532 1
# -87 88 1
# 198 -197 1
# 966 -965 1
# -852 853 1
# -172 173 1
# 172 -171 1
# 852 -851 1
# -485 486 1
# 675 -674 1
# -347 348 1
# 165 -164 1
# 537 -536 1
# -232 233 1
# 216 -215 1
# 984 -983 1
# -575 576 1
# 481 -480 1
# 577 -576 1
# -256 257 1
# -128 129 1
# 256 -255 1
# 384 -383 1
# -5 6 1
# -655 656 1
# -583 584 1
# -195 196 1
# 177 -176 1
# -188 189 1
# 188 -187 1
# 11 -10 1
# 467 -466 1
# 367 -366 1
# -435 436 1
# 589 -588 1
# -248 249 1
# 232 -231 1
# 1000 -999 1
# -297 298 1
# 23 -22 1
# 222 -221 1
# -494 495 1
# -222 223 1
# 494 -493 1
# -426 427 1
# 426 -425 1
# -295 296 1
# -167 168 1
# 593 -592 1
# 871 -870 1
# -305 306 1
# 527 -526 1
# -998 999 1
# -230 231 1
# 230 -229 1
# 673 -672 1
# 998 -997 1
# -864 865 1
# 352 -351 1
# -434 435 1
# 434 -433 1
# 197 -196 1
# -776 777 1
# -8 9 1
# 248 -247 1
# -313 314 1
# 519 -518 1
# -341 342 1
# 51 -50 1
# 819 -818 1
# -442 443 1
# 442 -441 1
# 778 -777 1
# -778 779 1
# ...

# %%
def check(a, b):
    for i in range(n - 1):
        if li[i] * a + b != li[i + 1]:
            return False
    return True

n = int(input())
li = list(map(int, input().split()))

if n == 1:
    print('A')
elif n == 2:
    if li[0] == li[1]:
        print(li[0])
    else:
        print('A')
else:
    if li[0] == 0:
        if li[1] == 0:
            if check(0, 0):
                print(0)
            else:
                print('B')
        else:
            b = li[1] - li[0]
            v = li[2] - b
            if v % li[1] == 0:
                a = v // li[1]
                
                if check(a, b):
                    print(li[-1] * a + b)
                else:
                    print('B')
            else:
                print('B')
    else:
        rs = set()
        is_multi = False
        for b in range(-20000000, 20000000):
            v = li[1] - b
            if v % li[0] == 0:
                a = v // li[0]
                
                if check(a, b):
                    rs.add(li[-1] * a + b)
                    
                    if len(rs) >= 2:
                        is_multi = True
                        break
                        
        if not rs:
            print('B')
        elif is_multi:
            print('A')
        else:
            r = rs.pop()

            print(r)
# Out:
# 3
# 3 1 -1
# -3

# %% [markdown]
# https://www.acmicpc.net/problem/19535 ㄷㄷㄷㅈ

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

def nCk(n, k):
    if n < k:
        return 0
    if k < 0:
        return 0
    
    if n - k < k:
        k = n - k
        
    num = 1
    for i in range(n, n - k, -1):
        num *= i
    
    denom = 1
    for i in range(2, k + 1):
        denom *= i
        
    return num // denom

n = int(input())
edges = [list(map(int, input().split())) for _ in range(n - 1)]

li = [0] * (n + 1)
for a, b in edges:
    li[a] += 1
    li[b] += 1
    
c_g = 0
for i in range(1, n + 1):
    if li[i] >= 3:
        c_g += nCk(li[i], 3)
        
c_d = 0
for a, b in edges:
    c_d += (li[a] - 1) * (li[b] - 1)
    
if c_d > c_g * 3:
    print('D')
elif c_d < c_g * 3:
    print('G')
else:
    print('DUDUDUNGA')

# %% [markdown]
# https://www.acmicpc.net/problem/14864 줄서기

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

# https://github.com/tatyam-prime/SortedSet/blob/main/SortedMultiset.py
import math
from bisect import bisect_left, bisect_right, insort
from typing import Generic, Iterable, Iterator, TypeVar, Union, List
T = TypeVar('T')

class SortedMultiset(Generic[T]):
    BUCKET_RATIO = 50
    REBUILD_RATIO = 170

    def _build(self, a=None) -> None:
        "Evenly divide `a` into buckets."
        if a is None: a = list(self)
        size = self.size = len(a)
        bucket_size = int(math.ceil(math.sqrt(size / self.BUCKET_RATIO)))
        self.a = [a[size * i // bucket_size : size * (i + 1) // bucket_size] for i in range(bucket_size)]
    
    def __init__(self, a: Iterable[T] = []) -> None:
        "Make a new SortedMultiset from iterable. / O(N) if sorted / O(N log N)"
        a = list(a)
        if not all(a[i] <= a[i + 1] for i in range(len(a) - 1)):
            a = sorted(a)
        self._build(a)

    def __iter__(self) -> Iterator[T]:
        for i in self.a:
            for j in i: yield j

    def __reversed__(self) -> Iterator[T]:
        for i in reversed(self.a):
            for j in reversed(i): yield j
    
    def __len__(self) -> int:
        return self.size
    
    def __repr__(self) -> str:
        return "SortedMultiset" + str(self.a)
    
    def __str__(self) -> str:
        s = str(list(self))
        return "{" + s[1 : len(s) - 1] + "}"

    def _find_bucket(self, x: T) -> List[T]:
        "Find the bucket which should contain x. self must not be empty."
        for a in self.a:
            if x <= a[-1]: return a
        return a

    def __contains__(self, x: T) -> bool:
        if self.size == 0: return False
        a = self._find_bucket(x)
        i = bisect_left(a, x)
        return i != len(a) and a[i] == x

    def count(self, x: T) -> int:
        "Count the number of x."
        return self.index_right(x) - self.index(x)

    def add(self, x: T) -> None:
        "Add an element. / O(√N)"
        if self.size == 0:
            self.a = [[x]]
            self.size = 1
            return
        a = self._find_bucket(x)
        insort(a, x)
        self.size += 1
        if len(a) > len(self.a) * self.REBUILD_RATIO:
            self._build()

    def discard(self, x: T) -> bool:
        "Remove an element and return True if removed. / O(√N)"
        if self.size == 0: return False
        a = self._find_bucket(x)
        i = bisect_left(a, x)
        if i == len(a) or a[i] != x: return False
        a.pop(i)
        self.size -= 1
        if len(a) == 0: self._build()
        return True

    def lt(self, x: T) -> Union[T, None]:
        "Find the largest element < x, or None if it doesn't exist."
        for a in reversed(self.a):
            if a[0] < x:
                return a[bisect_left(a, x) - 1]

    def le(self, x: T) -> Union[T, None]:
        "Find the largest element <= x, or None if it doesn't exist."
        for a in reversed(self.a):
            if a[0] <= x:
                return a[bisect_right(a, x) - 1]

    def gt(self, x: T) -> Union[T, None]:
        "Find the smallest element > x, or None if it doesn't exist."
        for a in self.a:
            if a[-1] > x:
                return a[bisect_right(a, x)]

    def ge(self, x: T) -> Union[T, None]:
        "Find the smallest element >= x, or None if it doesn't exist."
        for a in self.a:
            if a[-1] >= x:
                return a[bisect_left(a, x)]
    
    def __getitem__(self, x: int) -> T:
        "Return the x-th element, or IndexError if it doesn't exist."
        if x < 0: x += self.size
        if x < 0: raise IndexError
        for a in self.a:
            if x < len(a): return a[x]
            x -= len(a)
        raise IndexError

    def index(self, x: T) -> int:
        "Count the number of elements < x."
        ans = 0
        for a in self.a:
            if a[-1] >= x:
                return ans + bisect_left(a, x)
            ans += len(a)
        return ans

    def index_right(self, x: T) -> int:
        "Count the number of elements <= x."
        ans = 0
        for a in self.a:
            if a[-1] > x:
                return ans + bisect_right(a, x)
            ans += len(a)
        return ans

n, m = map(int, input().split())
li = [list(map(int, input().split())) for _ in range(m)]

ms = SortedMultiset()
for i in range(1, n + 1):
    ms.add(i)
    
ct = [0] * (n + 1)
for a, b in li:
    ct[a] += 1
    
result = [0] * (n + 1)
ip = True
for i in range(1, n + 1):
    if ct[i] > len(ms):
        ip = False
        break
    
    result[i] = ms[ct[i]]
    ms.discard(ms[ct[i]])
    
if ip:
    for a, b in li:
        if result[a] < result[b]:
            ip = False
            break
            
if ip:
    print(*result[1:])
else:
    print(-1)
# Out:
# 5 6
# 1 2
# 1 3
# 1 5
# 2 5
# 3 4
# 3 5
# -1

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

n, m = map(int, input().split())
li = [list(map(int, input().split())) for _ in range(m)]

result = list(range(n + 1))
for a, b in li:
    result[a] += 1
    result[b] -= 1
    
ip = True
for a, b in li:
    if result[a] < result[b]:
        ip = False
        break
            
if ip:
    print(*result[1:])
else:
    print(-1)
# Out:
# 5 5
# 1 2
# 1 5
# 3 4
# 3 5
# 4 5
# 3 1 5 4 2

# %%
import sys
input = lambda: sys.stdin.readline().rstrip()

n, m = map(int, input().split())
li = [list(map(int, input().split())) for _ in range(m)]

result = list(range(n + 1))
for a, b in li:
    result[a] += 1
    result[b] -= 1

result.pop(0)

ip = True
if len(set(result)) != n:
    ip = False
        
if ip:
    print(*result)
else:
    print(-1)

# %% [markdown]
# https://www.acmicpc.net/problem/2487 섞기 수열

# %%
from math import gcd

lcm = lambda a, b: a * b // gcd(a, b)

get_value = lambda x: int(x) - 1

n = int(input())
li = list(map(get_value, input().split()))

vt = [False] * n
r = 1
for i in range(n):
    if vt[i]:
        continue
    vt[i] = True
    
    st = {i}
    while True:
        i = li[i]
        if vt[i]:
            break
        vt[i] = True
        st.add(i)
        
    r = lcm(r, len(st))
    
print(r)
# Out:
# 3
# 2 3 1
# 3

# %% [markdown]
# https://www.acmicpc.net/problem/1407 2로 몇 번 나누어질까

# %%
3 ~ 8

3  4     5   6   7   8
1, 2,2   1   2   1  2,2,2
# Out:
# 11

# %%
a, b = map(int, input().split())

total = 0
fc = 0
cur = 2 ** 50
for _ in range(50, -1, -1):
    temp = a % cur
    if temp != 0:
        min_p = a + cur - temp
    else:
        min_p = a

    temp = b % cur
    max_p = b - temp
    
    c = 0
    if min_p <= max_p:
        c = max_p // cur - min_p // cur + 1
        
    total += (c - fc) * cur
    fc = c
    
    cur //= 2
    
print(total)
# Out:
# 176 177
# 17

# %% [markdown]
# https://www.acmicpc.net/problem/15668 방 번호

# %%
from itertools import permutations as perm

def check(n):
    for num in range(1, 6):
        for a_case in perm(range(0, 10), num):
            a_st = set(a_case)
            a = int(''.join(map(str, a_case)))
            
            b = n - a
            
            if a <= 0 or b <= 0:
                continue
            
            sb = str(b)
            b_st = set(map(int, sb))
            if len(b_st) != len(sb):
                continue
            
            if not a_st & b_st:
                return a, b
            
    return -1, -1

n = int(input())

a, b = check(n)
if a == b == -1:
    print(-1)
else:
    print(a, '+', b)
# Out:
# 2
# -1

# %% [markdown]
# https://www.acmicpc.net/problem/16282 Black Chain

# %%
n = int(input())

if n == 1:
    print(0)
elif n <= 3:
    print(1)
else:
    to_make = 1
    left = n

    num = 1
    start = 1
    end = 101
    r = -1
    while start <= end:
        mid = (start + end) // 2
        
        cur = mid
        for _ in range(mid):
            cur = cur * 2 + 1
            
        left = n - cur
        if cur + 1 >= left:
            r = mid
            end = mid - 1
        else:
            start = mid + 1
            
    print(r)
# Out:
# 6
# 1

# %%
2 ** 100 > 1e18
# Out:
# True

# %% [markdown]
# https://www.acmicpc.net/problem/2551 두 대표 자연수

# %%
inf = float('inf')

n = int(input())
li = sorted(map(int, input().split()))

r1 = li[(n - 1) // 2]

sv = sum(li)
cands = [sv // n - 1, sv // n, sv // n + 1]
r2 = 6000000
min_diff = inf
for cand in cands:
    temp = 0
    for v in li:
        temp += (v - cand) ** 2
        
    if temp < min_diff:
        min_diff = temp
        r2 = cand
    elif temp == min_diff and cand < r2:
        r2 = cand
        
print(r1, r2)
# Out:
# 2
# 1 2
# 1 1

# %% [markdown]
# https://www.acmicpc.net/problem/1891 사분면

# %%
def find_coord(i, sx, ex, sy, ey):
    if i == d:
        return sx, sy
    
    x_right_start = sx + (ex - (sx - 1)) // 2
    y_right_start = sy + (ey - (sy - 1)) // 2
    
    if li[i] == 1:
        return find_coord(i + 1, x_right_start, ex, y_right_start, ey)
    elif li[i] == 2:
        return find_coord(i + 1, sx, x_right_start - 1, y_right_start, ey)
    elif li[i] == 3:
        return find_coord(i + 1, sx, x_right_start - 1, sy, y_right_start - 1)
    elif li[i] == 4:
        return find_coord(i + 1, x_right_start, ex, sy, y_right_start - 1)

def find_loc(sx, ex, sy, ey):
    global result
    
    if sx == x == ex and sy == y == ey:
        result = temp.copy()
        return
    if x < sx or x > ex or y < sy or y > ey:
        return
    
    x_right_start = sx + (ex - (sx - 1)) // 2
    y_right_start = sy + (ey - (sy - 1)) // 2
    
    temp.append(1)
    find_loc(x_right_start, ex, y_right_start, ey)
    temp.pop()
    
    temp.append(2)
    find_loc(sx, x_right_start - 1, y_right_start, ey)
    temp.pop()
    
    temp.append(3)
    find_loc(sx, x_right_start - 1, sy, y_right_start - 1)
    temp.pop()
    
    temp.append(4)
    find_loc(x_right_start, ex, sy, y_right_start - 1)
    temp.pop()
    
d, li = input().split()
d = int(d)
li = list(map(int, li))

dx, dy = map(int, input().split())
    
x, y = find_coord(0, 1, 2 ** d, 1, 2 ** d)

x += dx
y += dy

if x <= 0 or x > 2 ** d or y < 0 or y > 2 ** d:
    print(-1)
else:
    temp = []
    find_loc(1, 2 ** d, 1, 2 ** d)
    
    r = ''.join(map(str, result))
    
    print(r)
# Out:
# 3 341
# 2 1
# 424

# %% [markdown]
# https://www.acmicpc.net/problem/13250 주사위 게임

# %%
dp[2] = 1 * (5 / 6) + (dp[1] + 1) * (1 / 6)
dp[3] = 1 * (4 / 6) + (dp[1] + 1) * (1 / 6) + (dp[2] + 1) * (1 / 6)

# %%
n = int(input())

dp = [0] * (n + 1)
dp[1] = 1

for num in range(2, min(n, 6) + 1):
    dp[num] = 1 * ((7 - num) / 6)
    for nnum in range(1, num):
        dp[num] += (dp[nnum] + 1) * (1 / 6)
        
for num in range(7, n + 1):
    temp = 0
    for nnum in range(num - 1, num - 7, -1):
        temp += (dp[nnum] + 1) * (1 / 6)
    dp[num] = temp

r = dp[n]

print(r)
# Out:
# 7
# 2.5216263717421126

# %% [markdown]
# https://www.acmicpc.net/problem/20302 민트 초코

# %%
from collections import defaultdict as dd

max_num = 100001
sp = [0] * (max_num + 1)
primes = []
for i in range(2, max_num + 1):
    if sp[i] == 0:
        sp[i] = i
        primes.append(i)
        
    j = 0
    while j < len(primes) and i * primes[j] <= max_num and primes[j] <= sp[i]:
        sp[i * primes[j]] = primes[j]
        j += 1

n = int(input())
li = input().split()

num = dd(int)
denom = dd(int)

is_zero = False

v = abs(int(li[0]))
if v == 0:
    is_zero = True
while v > 1:
    num[sp[v]] += 1
    v //= sp[v]

for i in range(1, len(li), 2):
    li[i + 1] = abs(int(li[i + 1]))
    v = li[i + 1]

    if li[i] == '*':
        if v == 0:
            is_zero = True
            break
        
        while v > 1:
            num[sp[v]] += 1
            v //= sp[v]
    else:
        while v > 1:
            denom[sp[v]] += 1
            v //= sp[v]
        
if is_zero:
    print('mint chocolate')
else:
    ip = True
    for key in denom:
        if denom[key] > num[key]:
            ip = False
            break
            
    if ip:
        print('mint chocolate')
    else:
        print('toothpaste')
# Out:
# 4
# 0 * 2 / 3 * 2
# toothpaste

# %%
max_num = 100001
sp = [0] * (max_num + 1)
primes = []
for i in range(2, max_num + 1):
    if sp[i] == 0:
        sp[i] = i
        primes.append(i)
        
    j = 0
    while j < len(primes) and i * primes[j] <= max_num and primes[j] <= sp[i]:
        sp[i * primes[j]] = primes[j]
        j += 1

n = int(input())
li = input().split()

ct = [0] * 100001

is_zero = False

v = abs(int(li[0]))
if v == 0:
    is_zero = True
while v > 1:
    ct[sp[v]] += 1
    v //= sp[v]

if not is_zero:
    for i in range(1, len(li), 2):
        v = abs(int(li[i + 1]))
        is_div = li[i] == '/'

        if v == 0:
            is_zero = True
            break

        while v > 1:
            ct[sp[v]] += 1 - 2 * is_div
            v //= sp[v]
        
if is_zero:
    print('mint chocolate')
else:
    ip = True
    for p in primes:
        if ct[p] < 0:
            ip = False
            break
            
    if ip:
        print('mint chocolate')
    else:
        print('toothpaste')
# Out:
# 6
# 1 * 1 * 1 * 1 * 1 * 1
# mint chocolate
